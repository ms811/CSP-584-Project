# %%
from yelpapi import YelpAPI

from pprint import pprint

yelp_api = YelpAPI('B_eJRBbtDZzdWqUPIEjSz9xwA-D_fo7IoPa-niJsmtY1sPCZ_SheuA3DgxmXntySdCkm3i2eTTlQBVce94hlD2WOPTM7NU4h1O_t_jTMrV8biAsW4KpTr7ZboINqXnYx')

# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")


df__business_reviews = pd.DataFrame()

list_of_restaurants = []

# %%
# chicago_downtown_zipcodes = [60601, 60602, 60603, 60604, 60605, 60606, 60607, 60608, 60610, 60611, 60612, 60616]
chicago_downtown_zipcodes = [60616]

for zip_code in chicago_downtown_zipcodes:
    for x in range(20):
        response = yelp_api.search_query(categories='Breakfast', 
                                     location=zip_code, 
                                 sort_by='rating', limit=50, offset=x*50)
        df__business_reviews = df__business_reviews.append(pd.DataFrame(response['businesses']))

        for review in response['businesses']: 
            index_review = {
                "name": review['name'],
                "image":review['image_url'],
                "contactno":review['display_phone'],
                "url" : review['url'],
                "rating":review['rating']
            }
            print(index_review)
            list_of_restaurants.append(index_review)
# Out:
# {'name': 'Art Institute of Chicago', 'image': 'https://s3-media2.fl.yelpcdn.com/bphoto/kp9B8BG7JVFvcMvk4s1PzA/o.jpg', 'contactno': '(312) 443-3600', 'url': 'https://www.yelp.com/biz/art-institute-of-chicago-chicago-3?adjust_creative=Gd-N17hhrVzzpru-eSZYUQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Gd-N17hhrVzzpru-eSZYUQ', 'rating': 4.5}
# {'name': 'Millennium Park', 'image': 'https://s3-media1.fl.yelpcdn.com/bphoto/ElWdmI18LCGGUy1_A2CuxQ/o.jpg', 'contactno': '(312) 742-1168', 'url': 'https://www.yelp.com/biz/millennium-park-chicago?adjust_creative=Gd-N17hhrVzzpru-eSZYUQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Gd-N17hhrVzzpru-eSZYUQ', 'rating': 4.5}
# ...

# %%
df__business_reviews.tail()
# Out:
#                         id                                      alias  \
# 45  Sfksgw-HhhSRvXRCkX5u4A                            pier-31-chicago
# 46  i4YV88dn3f5vufLX7RTffg  chinese-kitchen-sushi-and-grill-chicago-2
# 47  1uGrUoIvjajEv-VTcFzLWA                         lao-yunnan-chicago
# 48  sKC1JXbzybWmWdBDZvSP4g                             aire-chicago-2
# 49  z33SlompX5P2Uvf7gh7bzQ                       just-salad-chicago-2
#
#                                name  \
# 45                          Pier 31
# 46  Chinese Kitchen Sushi and Grill
# 47                       Lao Yunnan
# 48                             AIRE
# 49                       Just Salad
#
#                                             image_url  is_closed  \
# 45  https://s3-media2.fl.yelpcdn.com/bphoto/bVorVd...      False
# 46  https://s3-media2.fl.yelpcdn.com/bphoto/7hvizZ...      False
# 47  https://s3-media3.fl.yelpcdn.com/bphoto/PWdIIp...      False
# ...

# %%
import pymysql

import pandas as a

conn=pymysql.connect(host='localhost',port=int(3306),user='root',passwd='root',db='project')

df=a.read_sql_query("select* from login ",conn)

print(df)
# Out:
#       user pass      usertype
# 0        a    a      Customer
# 1  akshith   ak      Customer
# 2        d    d  StoreManager
# 3        s    s  StoreManager
# 4        t    t      Customer
# 5       we   we      Customer
# 6        x    x      Customer

# %%
list_of_unique_restaurants = []
check = []
for i in list_of_restaurants:
    if i['name'] not in check and i['rating'] == 5:
        check.append(i['name'])
        list_of_unique_restaurants.append(i)

for j in list_of_unique_restaurants:
    print(j)
# Out:
# {'name': "Bob's Pizza", 'image': 'https://s3-media3.fl.yelpcdn.com/bphoto/NtA_-fyc9l991m2TNvMcnA/o.jpg', 'contactno': '(312) 600-6155', 'url': 'https://www.yelp.com/biz/bobs-pizza-chicago?adjust_creative=Gd-N17hhrVzzpru-eSZYUQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Gd-N17hhrVzzpru-eSZYUQ', 'rating': 5.0}
# {'name': 'Firenze Italian Street Food', 'image': 'https://s3-media2.fl.yelpcdn.com/bphoto/tTBGQWst7ebK2_0TivGyag/o.jpg', 'contactno': '(781) 606-0112', 'url': 'https://www.yelp.com/biz/firenze-italian-street-food-chicago?adjust_creative=Gd-N17hhrVzzpru-eSZYUQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Gd-N17hhrVzzpru-eSZYUQ', 'rating': 5.0}
# ...

# %%
import pymysql

import pandas as a

conn=pymysql.connect(host='localhost',port=int(3306),user='root',passwd='root',db='project')
for each in list_of_unique_restaurants:
    df=a.read_sql_query("INSERT INTO morning(name,image,contactno,url,rating) VALUES("+each['name']+","+each['image']+","+each['contactno']+","+each['url']+","+str(each['rating']),conn)

print(df)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#
# ...

# %%
import mysql.connector

conn=pymysql.connect(host='localhost',user='root',passwd='root',db='project')

mycursor = mydb.cursor()


sql = "INSERT INTO morning (name,image,contactno,url,rating) VALUES (%s, %s, %s, %s,%s)"

for each in list_of_unique_restaurants:
#     val = (""+each['name']+","+each['image']+","+each['contactno']+","+each['url']+"," +str(each['rating']+")
    val = ("John", "Highway 21","24534","sfdsdfg","sfgsd")
    print(val)
    mycursor.execute(sql, (val))
mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# ('John', 'Highway 21', '24534', 'sfdsdfg', 'sfgsd')
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-102-e4d7dc28d277> in <module>
#      12     val = ("John", "Highway 21","24534","sfdsdfg","sfgsd")
#      13     print(val)
# ---> 14     mycursor.execute(sql, (val))
#      15 mydb.commit()
#      16
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ...

# %%
import mysql.connector

mydb = pymysql.connect(host='localhost',user='root',passwd='root',db='project')

mycursor = mydb.cursor()

sql = "INSERT INTO morning (name,image,contactno,url,rating) VALUES (%s, %s, %s, %s)"
val = ("John", "Highway 2,1123",)
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-19ee85a1dd5c> in <module>
#       7 sql = "INSERT INTO morning (name,image,contactno,url,rating) VALUES (%s, %s, %s, %s)"
#       8 val = ("John", "Highway 2,1123",)
# ----> 9 mycursor.execute(sql, val)
#      10
#      11 mydb.commit()
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     159             pass
#     160
# --> 161         query = self.mogrify(query, args)
#     162
#     163         result = self._query(query)
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in mogrify(self, query, args)
#     138
#     139         if args is not None:
# --> 140             query = query % self._escape_args(args, conn)
#     141
#     142         return query
#
# TypeError: not enough arguments for format string
